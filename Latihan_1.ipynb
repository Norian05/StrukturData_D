# %% [markdown]
# <a href="https://colab.research.google.com/github/Norian05/StrukturData_D/blob/main/Latihan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 5 Nama Mahasiswa

# %%
mahasiswa = ["Fajar", "Zidane", "Nero", "Yan", "Puja"]
x = mahasiswa
print ("List Mahasiswa : ")
print (x)
# Out:
# List Mahasiswa :
# ['Fajar', 'Zidane', 'Nero', 'Yan', 'Puja']

# %% [markdown]
# 2. Dihadirkan dengan .append

# %%
x.append("Marta")
print("Setelah ditambah Nama Baru")
print(x)
# Out:
# Setelah ditambah Nama Baru
# ['Fajar', 'Zidane', 'Nero', 'Yan', 'Puja', 'Marta']

# %% [markdown]
# 3. Dibungkam dengan .remove

# %%
mahasiswa.remove("Zidane")
print("Setelah diasingkan")
print(mahasiswa)
# Out:
# Setelah diasingkan
# ['Fajar', 'Nero', 'Yan', 'Puja', 'Marta']
